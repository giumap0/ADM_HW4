# %%
import os
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import sys
import numpy as np
import pandas as pd
import regex as re

# %%
url = 'https://www.immobiliare.it/vendita-case/roma/'
response = requests.get(url)

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.content)
# Out:
# b'<!DOCTYPE html>\n<!--[if IE 8]>\n<html class="lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!-->\n<html lang="it" prefix=""> <!--<![endif]-->\n<head>\n      <link rel="dns-prefetch" href="https://css.im-cdn.it">\n    <link rel="dns-prefetch" href="https://js.im-cdn.it">\n    <link rel="dns-prefetch" href="https://img.im-cdn.it">\n    <!--[if lte IE 10]>\n    <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Raleway:400,500&amp;subset=latin">\n<![endif]-->\n          <style>@charset "UTF-8";.container,.container-fluid{margin-right:auto;margin-left:auto}.container-fluid:after,.container-fluid:before,.container:after,.container:before,.row:after,.row:before{display:table;content:""}.btn-group-vertical>.btn,.btn-group>.btn,.btn-group>.btn-group,.btn-toolbar .btn,.btn-toolbar .btn-group,.btn-toolbar .input-group,.col-xs-0,.col-xs-1,.col-xs-10,.col-xs-11,.col-xs-12,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9,.dropdown-menu,.nav-pills>li,.nav-tabs>li{float:left}hr,input[type=search]{box-sizing:content-box}.text-hide,a{background-color:transparent}.container,.container-fluid{padding-left:0;padding-right:0}.btn,.styled-checkbox label{-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none}.dropdown-menu,.media-list,.nav{list-style:none}.btn-group-vertical>.btn-group:after,.btn-toolbar:after,.clearfix:after,.container-fluid:after,.container:after,.dl-horizontal dd:after,.dropdown-menu>li>a,.form-horizontal .form-group:after,.row:after{clear:both}.btn,.styled-checkbox .styled-check+span,.styled-checkbox label{-webkit-touch-callout:none;-khtml-user-select:none}.notify--in,.notify--out{animation-name:notifySlideUp}@font-face{font-family:Raleway;font-style:normal;font-weight:400;src:local("Raleway"),local("Raleway-Regular"),url(https://css.im-cdn.it/assets/287502315/fonts/raleway-reg-287502315.woff2) format("woff2"),url(https://css.im-cdn.it/assets/3649781113/fonts/raleway-reg-3649781113.woff) format("woff")}@font-face{font-family:Raleway;font-style:normal;font-weight:500;src:local("Raleway Medium"),local("Raleway-Medium"),url(https://css.im-cdn.it/assets/3460627194/fonts/raleway-med-3460627194.woff2) format("woff2"),url(https://css.im-cdn.it/assets/3333674517/fonts/raleway-med-3333674517.woff) format("woff")}@font-face{font-family:Raleway;font-style:normal;font-weight:600;src:local("Raleway SemiBold"),local("Raleway-SemiBold"),url(https://css.im-cdn.it/assets/433986225/fonts/raleway-sb-433986225.woff2) format("woff2"),url(https://css.im-cdn.it/assets/2487882556/fonts/raleway-sb-2487882556.woff) format("woff")}@media print,screen and (min-width:768px){.container{width:750px}}@media print,screen and (min-width:1024px){.container{width:1024px}}@media print,screen and (min-width:1280px){.container{width:1280px}}.row{margin-left:0;margin-right:0}.col-lg-1,.col-lg-10,.col-lg-11,.col-lg-12,.col-lg-2,.col-lg-3,.col-lg-4,.col-lg-5,.col-lg-6,.col-lg-7,.col-lg-8,.col-lg-9,.col-md-1,.col-md-10,.col-md-11,.col-md-12,.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9,.col-sm-1,.col-sm-10,.col-sm-11,.col-sm-12,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9,.col-xs-1,.col-xs-10,.col-xs-11,.col-xs-12,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9{position:relative;min-height:1px;padding-left:0;padding-right:0}.col-xs-0{width:0%}.col-xs-1{width:8.3333333333%}.col-xs-2{width:16.6666666667%}.col-xs-3{width:25%}.col-xs-4{width:33.3333333333%}.col-xs-5{width:41.6666666667%}.col-xs-6{width:50%}.col-xs-7{width:58.3333333333%}.col-xs-8{float:left;width:66.6666666667%}.col-xs-9{width:75%}.col-xs-10{width:83.3333333333%}.col-xs-11{width:91.6666666667%}.col-xs-12{width:100%}@media print,screen and (min-width:768px){.col-sm-0,.col-sm-1,.col-sm-10,.col-sm-11,.col-sm-12,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9{float:left}.col-sm-0{width:0%}.col-sm-1{width:8.3333333333%}.col-s ...

# %% [markdown]
# This will print data in format like we have seen when we inspected the web page.

# %%
soup = BeautifulSoup(response.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]>
# <html class="lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="it" prefix="">
#  <!--<![endif]-->
#  <head>
#   <link href="https://css.im-cdn.it" rel="dns-prefetch"/>
#   <link href="https://js.im-cdn.it" rel="dns-prefetch"/>
#   <link href="https://img.im-cdn.it" rel="dns-prefetch"/>
#   <!--[if lte IE 10]>
#     <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Raleway:400,500&amp;subset=latin">
# <![endif]-->
#   <style>
#    @charset "UTF-8";.container,.container-fluid{margin-right:auto;margin-left:auto}.container-fluid:after,.container-fluid:before,.container:after,.container:before,.row:after,.row:before{display:table;content:""}.btn-group-vertical>.btn,.btn-group>.btn,.btn-group>.btn-group,.btn-toolbar .btn,.btn-toolbar .btn-group,.btn-toolbar .input-group,.col-xs-0,.col-xs-1,.col-xs-10,.col-xs-11,.col-xs-12,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9,.dropdown-menu,.nav-pills>li,.nav-tabs>li{float:left}hr,input[type=search]{box-sizing:content-box}.text-hide,a{background-color:transparent}.container,.container-fluid{padding-left:0;padding-right:0}.btn,.styled-checkbox label{-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none}.dropdown-menu,.media-list,.nav{list-style:none}.btn-group-vertical>.btn-group:after,.btn-toolbar:after,.clearfix:after,.container-fluid:after,.container:after,.dl-horizontal dd:after,.dropdown-menu>li>a,.form-horizontal .form-group:after,.row:after{clear:both}.btn,.styled-checkbox .styled-check+span,.styled-checkbox label{-webkit-touch-callout:none;-khtml-user-select:none}.notify--in,.notify--out{animation-name:notifySlideUp}@font-face{font-family:Raleway;font-style:normal;font-weight:400;src:local("Raleway"),local("Raleway-Regular"),url(https://css.im-cdn.it/assets/287502315/fonts/raleway-reg-287502315.woff2) format("woff2"),url(https://css.im-cdn.it/assets/3649781113/fonts/raleway-reg-3649781113.woff) format("woff")}@font-face{font-family:Raleway;font-style:normal;font-weight:500;src:local("Raleway Medium"),local("Raleway-Medium"),url(https://css.im-cdn.it/assets/3460627194/fonts/raleway-med-3460627194.woff2) format("woff2"),url(https://css.im-cdn.it/assets/3333674517/fonts/raleway-med-3333674517.woff) format("woff")}@font-face{font-family:Raleway;font-style:normal;font-weight:600;src:local("Raleway SemiBold"),local("Raleway-SemiBold"),url(https://css.im-cdn.it/assets/433986225/fonts/raleway-sb-433986225.woff2) format("woff2"),url(https://css.im-cdn.it/assets/2487882556/fonts/raleway-sb-2487882556.woff) format("woff")}@media print,screen and (min-width:768px){.container{width:750px}}@media print,screen and (min-width:1024px){.container{width:1024px}}@media print,screen and (min-width:1280px){.container{width:1280px}}.row{margin-left:0;margin-right:0}.col-lg-1,.col-lg-10,.col-lg-11,.col-lg-12,.col-lg-2,.col-lg-3,.col-lg-4,.col-lg-5,.col-lg-6,.col-lg-7,.col-lg-8,.col-lg-9,.col-md-1,.col-md-10,.col-md-11,.col-md-12,.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9,.col-sm-1,.col-sm-10,.col-sm-11,.col-sm-12,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9,.col-xs-1,.col-xs-10,.col-xs-11,.col-xs-12,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9{position:relative;min-height:1px;padding-left:0;padding-right:0}.col-xs-0{width:0%}.col-xs-1{width:8.3333333333%}.col-xs-2{width:16.6666666667%}.col-xs-3{width:25%}.col-xs-4{width:33.3333333333%}.col-xs-5{width:41.6666666667%}.col-xs-6{width:50%}.col-xs-7{width:58.3333333333%}.col-xs-8{float:left;width:66.6666666667%}.col-xs-9{width:75%}.col-xs-10{width:83.3333333333%}.col-xs-11{width:91.6666666667%}.col-xs-12{width:100%}@media print,screen and (min-width:768px){.col-sm-0,.col-sm-1,.col-sm-10,.col-sm-11,.col-sm-12,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9{float:left}.col-sm-0{width:0%}.col-sm-1{width:8.3333333333%}.col-sm-2{width:16.6666666667%}.col-sm-3{width:25%}.col-sm-4{width:33.3333333333%}.col-sm-5{float:left;width:41.6666666667%}.col-sm-6{width:50%}.col-sm-7{width:58.3333333333%}.col-sm-8{width:66.6666666667%}.col-sm-9{width:75%}.col-sm-10{width:83.3333333333%}.col-sm-11{width:91.6666666667%}.col-sm-12{width:100%}}@media print,screen and (min-width:1024px){.col-md-0,.col-md-1,.col-md-10,.col-md-11,.col-md-12,.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9{float:le ...
#   </style>
#   <!--[if IE 8]>
#         <link href="https://css.im-cdn.it/assets/2018112701/css/ie.css" rel="stylesheet" />
#     <![endif]-->
#   <style>
#    @charset "UTF-8";.block__data,.listing-item{overflow:hidden;position:relative}.icona__filtri--blu,.icona__ordina--blu{fill:#216a95}.agenzie-list,.breadcrumb-immobiliare,.cookie-bar,.listing-block,.search-form-tabs>li>a>span{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.cookie-bar{background-color:rgba(0,0,0,.8);color:#fff;padding-top:15px;padding-bottom:15px;display:none}.lt-ie9 .cookie-bar{background:0 0;filter:progid:DXImageTransform.Microsoft.gradient(startColorstr=#CC000000, endColorstr=#CC000000);zoom:1}.cookie-bar__container{display:table}.cookie-bar__content{display:table-cell;vertical-align:middle;font-size:14px}.cookie-bar__link{cursor:pointer;text-decoration:underline}.cookie-bar__actions{display:table-cell;vertical-align:middle;text-align:right}.cookie-bar--visible{display:block}@media (max-width:767px){.cookie-bar__content{font-size:13px}}.pagination{padding-left:0;margin:20px 0;border-radius:2px}.pagination>li{display:inline}.pagination>li>a,.pagination>li>span{position:relative;float:left;padding:8px 12px;line-height:1.428571429;text-decoration:none;color:#337ab7;background-color:#fff;margin-left:-1px}.pagination>li:first-child>a,.pagination>li:first-child>span{margin-left:0;border-bottom-left-radius:2px;border-top-left-radius:2px}.pagination>li:last-child>a,.pagination>li:last-child>span{border-bottom-right-radius:2px;border-top-right-radius:2px}.pagination>li>a:focus,.pagination>li>a:hover,.pagination>li>span:focus,.pagination>li>span:hover{z-index:2;color:#666;background-color:#e6e5e5;border-color:#ddd}.pagination>.active>a,.pagination>.active>a:focus,.pagination>.active>a:hover,.pagination>.active>span,.pagination>.active>span:focus,.pagination>.active>span:hover{z-index:3;color:#fff;background-color:#2b6481;border-color:#2b6481;cursor:default}.pagination>.disabled>a,.pagination>.disabled>a:focus,.pagination>.disabled>a:hover,.pagination>.disabled>span,.pagination>.disabled>span:focus,.pagination>.disabled>span:hover{color:#777;background-color:#fff;border-color:#ddd;cursor:default}.pagination-lg>li>a,.pagination-lg>li>span{padding:11px 16px;font-size:18px;line-height:1.3333333}.pagination-lg>li:first-child>a,.pagination-lg>li:first-child>span{border-bottom-left-radius:6px;border-top-left-radius:6px}.pagination-lg>li:last-child>a,.pagination-lg>li:last-child>span{border-bottom-right-radius:6px;border-top-right-radius:6px}.pagination-sm>li>a,.pagination-sm>li>span{padding:6px 10px;font-size:12px;line-height:1.5}.pagination-sm>li:first-child>a,.pagination-sm>li:first-child>span{border-bottom-left-radius:3px;border-top-left-radius:3px}.pagination-sm>li:last-child>a,.pagination-sm>li:last-child>span{border-bottom-right-radius:3px;border-top-right-radius:3px}@-ms-viewport{width:device-width}.visible-lg,.visible-lg-block,.visible-lg-inline,.visible-lg-inline-block,.visible-md,.visible-md-block,.visible-md-inline,.visible-md-inline-block,.visible-sm,.visible-sm-block,.visible-sm-inline,.visible-sm-inline-block,.visible-xs,.visible-xs-block,.visible-xs-inline,.visible-xs-inline-block{display:none!important}@media (max-width:767px){.visible-xs{display:block!important}table.visible-xs{display:table!important}tr.visible-xs{display:table-row!important}td.visible-xs,th.visible-xs{display:table-cell!important}.visible-xs-block{display:block!important}.visible-xs-inline{display:inline!important}.visible-xs-inline-block{display:inline-block!important}}@media (min-width:768px) and (max-width:1023px){.visible-sm{display:block!important}table.visible-sm{display:table!important}tr.visible-sm{display:table-row!important}td.visible-sm,th.visible-sm{display:table-cell!important}.visible-sm-block{display:block!important}.visible-sm-inline{display:inline!important}.visible-sm-inline-block{display:inline-block!important}}@media (min-width:1024px) and (max-width:1279px){.visible-md{display:block!important}table.visible-md{display:table!important}tr.visible-md{display:table-row!important}td.visible-md,th.visib ...
#   </style>
#   <script type="text/javascript">
#    function noCookie() {
#         return null;
#     }
#     try {
#         if (navigator.cookieEnabled) {
#             function readCookie(b) {
#                 var f = b + '=';
#                 var a = document.cookie.split(';');
#                 for (var d = 0; d < a.length; d++) {
#                     var g = a[d];
#                     while (g.charAt(0) == ' ') {
#                         g = g.substring(1, g.length);
#                     }
#                     if (g.indexOf(f) == 0) {
#                         return g.substring(f.length, g.length);
#                     }
#                 }
#                 return null;
#             }
#         } else {
#             window.readCookie = noCookie;
#         }
#     } catch (e) {
#         window.readCookie = noCookie;
#     }
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="#2b6481" name="theme-color"/>
#   <meta content="always" name="referrer"/>
#   <link href="https://www.immobiliare.it/vendita-case/roma/" rel="canonical">
#    <link href="https://www.immobiliare.it/vendita-case/roma/?pag=2" rel="next">
#     <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#     <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1" name="viewport"/>
#     <title>
#      Case in vendita Roma - Immobiliare.it
#     </title>
#     <meta content="index,follow" name="robots">
#      <meta content="Case in vendita Roma" property="og:title">
#       <meta content="43.193 annunci di case in vendita a Roma. Scopri tutti gli annunci privati e di agenzie e scegli con Immobiliare.it la tua futura casa." property="og:description"/>
#       <meta content="" property="og:image"/>
#       <meta content="43.193 annunci di case in vendita a Roma. Scopri tutti gli annunci privati e di agenzie e scegli con Immobiliare.it la tua futura casa." name="Description"/>
#       <meta content="app-id=335948517, affiliate-data=ct=Smart-banner-safari&amp;pt=304468, app-argument=immogrp2://urlrev=2" name="apple-itunes-app"/>
#       <script>
#        var globalVars = {
#         'EXTERNAL_LIBRARY_VERSION': '?v=2018112701',
#         'MEDIA_SERVER': 'https://media.immobiliare.it/',
#         'MEDIA_SERVER_IMAGE': 'https://pic.im-cdn.it/',
#         'MAX_STATIC_POLYGON_THUMB_PREVIEW_POINTS': '50',
#         'GOOGLE_MAPS_KEY': 'AIzaSyBv8V_85Jtn9-VMbtMtqpiXHGmekuFAPfQ',
#         'GOOGLE_MAPS_VERSION': '?v=3.19',
#         'STATIC_MAP_URL': 'https://maps.im-cdn.it/static',
#         'VHOST_URL_HOST': 'https://www.immobiliare.it/',
#                 'VHOST_URL_JSON': 'https://js.im-cdn.it',
#                 'IS_PRODUCTION_ENVIRONMENT': 1,
#         'GOOGLE_ANALYTICS_CODE': 'UA-2884366-1',
#         'GOOGLE_ANALYTICS_DOMAIN': 'immobiliare.it',
#         'GOOGLE_ANALYTICS_UNIVERSAL_CODE': 'UA-2884366-10',
#         'ENABLE_COOKIE_BAR': 1,
#         'ENABLE_SENTRY_JS': 0,
#     };
#     var siteConfigs = {
#         isLoggedUser: false,
#                         FBappId: '199783830036103',
#                         mapsVersionPrefixPath: 'https://img.im-cdn.it/assets/2018112701',
#         imgVersionPrefixPath: 'https://img.im-cdn.it/assets/2018112701',
#                                 criteoAds: ["70453446","70454576","70457896"],
#                                                             imgMetrics: {"map_search_form":"https:\/\/s.ekbl.net\/s.gif?m=prod.sites.immobiliare.map.js.immobiliare.form_ricerca&h=9358dd&t=_&c=3087155592"},
#                 page: 'risultati',
#         reloadUserOnLogin: '1',
#         section: 'annunci_residenziali',
#         sub_section: 'annunci_residenziali',
#         vertical: ''
#     };
#       </script>
#       <script id="dfpBannerInitConfig" type="application/json">
#        {"banners":[{"id":"div-gpt-ad-1476096528895-0","name":"\/4767090\/Res_Lista_Box_300x250","width":"300","height":"250","display":1,"isActive":"1","setTargeting":{"Sezione":"risultatiV2","Categoria":1,"Contratto":1,"Nazione":"IT","Province":"RM","Comune":"6737"},"key":"banner_aside_1"},{"id":"div-gpt-ad-1476096613411-0","name":"\/4767090\/Res_Lista_Box_2_300x250","width":"300","height":"250","display":"1","isActive":"1","setTargeting":{"Sezione":"risultatiV2","Categoria":1,"Contratto":1,"Nazione":"IT","Province":"RM","Comune":"6737"},"key":"banner_aside_2"},{"id":"div-gpt-ad-1491564297386-0","name":"\/4767090\/Res_Mutui_Lista_Annunci_300x250","width":"300","height":"250","display":1,"isActive":"1","setTargeting":{"Sezione":"risultatiV2","Categoria":1,"Contratto":1,"Nazione":"IT","Province":"RM","Comune":"6737"},"key":"banner_aside_3"},{"id":"div-gpt-ad-1476095996101-0","name":"\/4767090\/Res_Lista_Annunci_LeaderBoard_Bottom_728x90","width":"728","height":"90","display":1,"isActive":"1","setTargeting":{"Sezione":"risultatiV2","Categoria":1,"Contratto":1,"Nazione":"IT","Province":"RM","Comune":"6737"},"key":"banner_bottom_1"},{"id":"div-gpt-ad-1490014782721-0","name":"\/4767090\/Res_Lista_Annunci_300x600","width":"300","height":"600","display":"1","isActive":"1","setTargeting":{"Sezione":"risultatiV2","Categoria":1,"Contratto":1,"Nazione":"IT","Province":"RM","Comune":"6737"},"key":"half_page_banner"},{"id":"div-gpt-ad-1476102471089-0","name":"\/4767090\/Res_Lista_Annunci_Banner_Centrale_660x150","width":"660","height":"150","display":"1","isActive":"1","setTargeting":{"Sezione":"risultatiV2","Categoria":1,"Contratto":1,"Nazione":"IT","Province":"RM","Comune":"6737"},"key":"banner_infralisting_1"},{"id":"div-gpt-ad-1476102425722-0","name":"\/4767090\/Res_Lista_Annunci_Banner_Centrale_2_660x150","width":"660","height":"150","display":"1","isActive":"1","setTargeting":{"Sezione":"risultatiV2","Categoria":1,"Contratto":1,"Nazione":"IT","Province":"RM","Comune":"6737"},"key":"banner_infralisting_2"},{"id":"div-gpt-ad-1476102362153-0","name":"\/4767090\/Res_Lista_Annunci_Banner_Centrale_3_660x150","width":"660","height":"150","display":"1","isActive":"1","setTargeting":{"Sezione":"risultatiV2","Categoria":1,"Contratto":1,"Nazione":"IT","Province":"RM","Comune":"6737"},"key":"banner_infralisting_3"},{"id":"div-gpt-ad-1484672117827-0","name":"\/4767090\/Res_Lista_Annunci_Banner_Centrale_4_660x150","width":"660","height":"150","display":"1","isActive":"1","setTargeting":{"Sezione":"risultatiV2","Categoria":1,"Contratto":1,"Nazione":"IT","Province":"RM","Comune":"6737"},"key":"banner_infralisting_4"},{"id":"div-gpt-ad-1510650478709-0","name":"\/4767090\/MobileApp_Infralisting_320x150","width":"320","height":"150","display":"1","isActive":"1","platform":"1","setTargeting":{"Sezione":"risultatiV2","Categoria":1,"Contratto":1,"Nazione":"IT","Province":"RM","Comune":"6737"},"key":"banner_infralisting_1_mobile"},{"id":"div-gpt-ad-1513697850537-0","name":"\/4767090\/Res_Infralisting_Mobile_320x50","width":"320","height":"50","display":"1","isActive":"1","platform":"1","setTargeting":{"Sezione":"risultatiV2","Categoria":1,"Contratto":1,"Nazione":"IT","Province":"RM","Comune":"6737"},"key":"banner_infralisting_2_mobile"}],"settings":{"nascondiSeVuoti":"1"}}
#       </script>
#       <!--[if gte IE 9]>
# <link rel="shortcut icon"
#       href="https://img.im-cdn.it/assets/2018112701/img2/touchIcons/ie9-favicon.ico"
#       type="image/x-icon"/>
# <![endif]-->
#       <link href="https://img.im-cdn.it/assets/2018112701/img2/touchIcons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144">
#        <link href="https://img.im-cdn.it/assets/2018112701/img2/touchIcons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#        <link href="https://img.im-cdn.it/assets/2018112701/img2/touchIcons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#        <link href="https://img.im-cdn.it/assets/2018112701/img2/touchIcons/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#        <link href="https://img.im-cdn.it/assets/2018112701/img2/touchIcons/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#        <link href="https://img.im-cdn.it/assets/2018112701/img2/touchIcons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#        <link href="https://img.im-cdn.it/assets/2018112701/img2/touchIcons/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#        <link href="https://img.im-cdn.it/assets/2018112701/img2/touchIcons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#        <link href="https://img.im-cdn.it/assets/2018112701/img2/touchIcons/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#        <link href="https://img.im-cdn.it/assets/2018112701/img2/touchIcons/apple-touch-icon.png" rel="apple-touch-icon"/>
#        <!--[if IE]>
# <meta name="msapplication-TileImage"
#       content="https://img.im-cdn.it/assets/2018112701/img2/touchIcons/mstile-144x144.png"/>
# <meta name="msapplication-TileColor" content="#319ACF"/>
# <![endif]-->
#        <meta content="Immobiliare.it" name="application-name">
#         <script>
#          ('ontouchstart' in window || navigator.maxTouchPoints) && (document.documentElement.className && (document.documentElement.className += ' '), document.documentElement.className += 'touch-device')
#         </script>
#         <script>
#          !('columns' in document.documentElement.style || '-webkit-columns' in document.documentElement.style || 'MozColumns' in document.documentElement.style) && (document.documentElement.className && (document.documentElement.className += ' '), document.documentElement.className += 'no-csscolumns')
#         </script>
#         <!--[if lte IE 9]>
#   <script src="https://js.im-cdn.it/assets/2018112701/js/polyfills-head.js"></script>
#   <![endif]-->
#         <!-- Turn off telephone number detection. -->
#         <meta content="telephone=no" name="format-detection"/>
#        </meta>
#       </link>
#      </meta>
#     </meta>
#    </link>
#   </link>
#  </head>
#  <body class="viewport-fluid viewport-fluid--full">
#   <!--googleoff: all-->
#   <div class="cookie-bar clearfix" data-cookie-name="cookieBanner" id="cookie-bar">
#    <div class="container cookie-bar__container">
#     <div class="cookie-bar__content">
#      Questo sito utilizza cookie tecnici e di terze parti. Continuando la navigazione ne accetti l'utilizzo.
#      <span class="cookie-bar__link js-link" data-href="/uso_dei_cookie.php">
#       Leggi informativa
#      </span>
#      .
#     </div>
#     <div class="cookie-bar__actions">
#      <span class="btn btn-white js-accept">
#       OK
#      </span>
#     </div>
#    </div>
#   </div>
#   <script>
#    !readCookie('cookieBanner') && (document.getElementById('cookie-bar').className += ' cookie-bar--visible')
#   </script>
#   <!--googleon: all-->
#   <!--googleoff: all-->
#   <div class="app__container js-app-banner" data-os="Android" id="android-app-banner">
#    <div class="container table-wrap">
#     <div class="app__close cell-wrap cell-wrap--middle js-close">
#     </div>
#     <div class="app__content cell-wrap cell-wrap--middle">
#      <p>
#       <strong>
#        Immobiliare.it
#       </strong>
#      </p>
#      <p>
#       Gratis per Android
#      </p>
#     </div>
#     <div class="cell-wrap cell-wrap--middle">
#      <a class="btn btn-action pull-right js-download" data-href="https://play.google.com/store/apps/details?id=it.immobiliare.android" target="_blank" title="App Android Immobiliare.it">
#       Scarica
#      </a>
#     </div>
#    </div>
#   </div>
#   <script>
#    navigator.userAgent.match(/android/i) && !navigator.userAgent.match(/Windows Phone/i) && readCookie('cookieBanner') && !readCookie('downloadApp') && (document.getElementById('android-app-banner').className += ' app__container--visible')
#   </script>
#   <!--googleon: all-->
#   <div class="navbar navbar-immobiliare header-slim" id="sticky-block" role="navigation">
#    <div class="container">
#     <div class="navbar navbar-main">
#      <span class="page-back visible-xs" id="page-back">
#      </span>
#      <a class="immobiliare-brand" href="https://www.immobiliare.it/">
#       <img alt="Immobiliare.it" height="34" src="https://img.im-cdn.it/assets/2018112701/img/common/logo-white.svg" width="180"/>
#       <!--[if lte IE 8]><img width="180" height="30" alt="Immobiliare.it" class="logoie8"
#                                     src="https://img.im-cdn.it/assets/2018112701/img/common/logo-header-slim.png"/><![endif]-->
#      </a>
#     </div>
#     <ul class="navbar navbar-right" id="offline-actions-user">
#      <li class="hidden-xs navigation__item">
#       <a href="/pubblica-annuncio-privati/?backurl=/utente/annuncio/nuovo/" rel="nofollow">
#        <i class="icon icon-publish">
#        </i>
#        <span>
#         Pubblica
#        </span>
#       </a>
#      </li>
#      <li class="hidden-xs navigation__item">
#       <a href="/accedi" id="btn-registra-utente" rel="nofollow">
#        <i class="icon icon-signup">
#        </i>
#        <span>
#         Registrati
#        </span>
#       </a>
#      </li>
#      <li class="navigation__item">
#       <a href="/accedi" id="btn-accedi-utente" rel="nofollow">
#        <i class="icon icon-user hidden-xs">
#        </i>
#        <span>
#         Accedi
#        </span>
#       </a>
#      </li>
#     </ul>
#     <ul class="navbar navbar-right hidden" id="online-actions-user">
#      <li class="hidden-xs navigation__item">
#       <a href="/pubblicaAnnunci.php" rel="nofollow">
#        <i class="icon icon-publish">
#        </i>
#        <span>
#         Pubblicati
#        </span>
#       </a>
#      </li>
#      <li class="hidden-xs navigation__item">
#       <a href="/bookmarkannunci.php" rel="nofollow">
#        <i class="icon icon-annunci">
#        </i>
#        <span>
#         Annunci
#        </span>
#       </a>
#      </li>
#      <li class="hidden-xs navigation__item">
#       <a href="/bookmarkricerche.php" rel="nofollow">
#        <i class="icon icon-ricerche">
#        </i>
#        <span>
#         Ricerche
#        </span>
#       </a>
#      </li>
#      <li class="navigation__item js-dropdown-user">
#       <a class="js-ud-button" href="#" rel="nofollow">
#        <i class="icon icon-user">
#        </i>
#        <span class="hidden-xs">
#         Profilo
#        </span>
#       </a>
#       <div class="js-ud-container">
#       </div>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <div class="body-content listing-page listing-block pos-relative">
#    <div class="searchmodule-stripe highlight two-row" id="search-form">
#     <div class="container">
#      <div class="searchmodule-wrap highlight">
#       <form action="javascript:void(0);" autocomplete="off" class="searchmodule-form" novalidate="">
#        <fieldset>
#         <div class="search-form-container">
#          <div class="search-form-header visible-xs-block">
#           <span class="closeMobile js-back-mobile">
#           </span>
#           <span>
#            Ricerca
#           </span>
#          </div>
#          <div class="scroll-mobile-wrap">
#           <div class="block-visible">
#            <div class="col-content col-content_contract">
#             <div class="dropdown dropdown-select filled" data-name="idContratto" data-role="select" tabindex="0">
#              <div class="dropdown-toggle form-control pointer component-form" data-action="toggle">
#               <div class="value-container">
#                <span class="placeholder">
#                </span>
#                <span data-role="display-value">
#                 Vendita
#                </span>
#               </div>
#              </div>
#              <div class="dropdown-menu select-menu__mobile">
#               <ul class="dropdown-select-menu" data-role="menu">
#                <li class="focus-hide" tabindex="0">
#                </li>
#                <li>
#                 <a class=" selected" data-value="1" role="button">
#                  Vendita
#                 </a>
#                </li>
#                <li>
#                 <a class="" data-value="2" role="button">
#                  Affitto
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#            </div>
#            <div class="col-content col-content_search">
#             <div class="" data-name="geodata" data-role="geoselect">
#              <div class="form-control searchmodule-suggestion-box flex-display">
#               <div class="searchmodule-suggestion">
#                <input class="searchmodule-suggestion-input" data-role="autocomplete" placeholder="Inserisci un comune o una provincia" value="Roma (Comune)"/>
#               </div>
#               <div class="searchmodule-locality-filters pull-right">
#                <a class="text-uppercase visible-xs visible-sm" data-action="open-map-modal" data-name="geodata" role="button">
#                 <span>
#                  modifica
#                 </span>
#                </a>
#                <a class="text-uppercase hidden-xs hidden-sm" data-action="open-map-modal" data-name="geodata" data-tab="1" role="button">
#                 <span>
#                  modifica località
#                 </span>
#                </a>
#                <a class="piped-left text-uppercase hidden-xs hidden-sm" data-action="open-map-modal" data-name="geodata" data-tab="2" role="button">
#                 <span>
#                  disegna su mappa
#                 </span>
#                </a>
#               </div>
#              </div>
#              <div class="hidden pos-relative" data-role="checklist-zone">
#              </div>
#              <div class="hidden pos-relative" data-role="checklist-localita">
#              </div>
#             </div>
#            </div>
#            <div class="col-content one-row-one-col col-content_tipologia">
#             <div class="dropdown-select" data-name="category" data-role="category">
#              <a class="form-control" data-action="open-modal" role="button">
#               <span class="value-container" data-role="display-value">
#                Residenziale
#               </span>
#               <span class="visible-xs-block caret-icon">
#               </span>
#              </a>
#              <div class="modal" role="dialog" tabindex="-1">
#               <div class="modal-dialog search-form-modal search-form-modal--tipology">
#                <div class="modal-content">
#                 <div class="modal-header">
#                  <a aria-label="Close" class="close" data-action="close" role="button">
#                   <span aria-hidden="true">
#                    ×
#                   </span>
#                  </a>
#                  <div class="x-scroll-mobile">
#                   <ul class="nav nav-justified tipology-filters-tablist" role="tablist">
#                    <li class=" active" data-role="tab-btn" data-value="0">
#                     <a data-action="select-category" role="button">
#                      Residenziale
#                     </a>
#                    </li>
#                    <li class="" data-role="tab-btn" data-value="1">
#                     <a data-action="select-category" role="button">
#                      Attività e licenze
#                     </a>
#                    </li>
#                    <li class="" data-role="tab-btn" data-value="2">
#                     <a data-action="select-category" role="button">
#                      Immobili commerciali
#                     </a>
#                    </li>
#                    <li class="" data-role="tab-btn" data-value="3">
#                     <a data-action="select-category" role="button">
#                      Nuove costruzioni
#                     </a>
#                    </li>
#                    <li class="" data-role="tab-btn" data-value="4">
#                     <a data-action="select-category" role="button">
#                      Stanze
#                     </a>
#                    </li>
#                    <li class="" data-role="tab-btn" data-value="5">
#                     <a data-action="select-category" role="button">
#                      Terreni
#                     </a>
#                    </li>
#                    <li class="" data-role="tab-btn" data-value="6">
#                     <a data-action="select-category" role="button">
#                      Aste
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                 </div>
#                 <div class="modal-body">
#                  <div class="tab-content tipology-filters-tab-content js-category-tab">
#                   <div class="tab-pane active clearfix">
#                    <div class="styled-radiobtn_container--select-all">
#                     <div class="styled-radiobtn">
#                      <label>
#                       <input name="styled-radio-basic" type="checkbox"/>
#                       <span class="styled-radio">
#                        <i>
#                        </i>
#                       </span>
#                       <span>
#                        Tutti
#                       </span>
#                      </label>
#                     </div>
#                    </div>
#                    <div class="col-xs-4">
#                     <div class="styled-radiobtn">
#                      <label>
#                       <input checked="checked" name="styled-radio-basic" type="checkbox"/>
#                       <span class="styled-radio">
#                        <i>
#                        </i>
#                       </span>
#                       <span>
#                        <a href="https://www.immobiliare.it/vendita-appartamenti/roma/" title="Appartamenti in vendita Roma">
#                         Appartamento
#                        </a>
#                       </span>
#                      </label>
#                     </div>
#                    </div>
#                    <div class="col-xs-4">
#                     <div class="styled-radiobtn">
#                      <label>
#                       <input name="styled-radio-basic" type="checkbox"/>
#                       <span class="styled-radio">
#                        <i>
#                        </i>
#                       </span>
#                       <span>
#                        <a href="https://www.immobiliare.it/vendita-attici/roma/" title="Attici in vendita Roma">
#                         Attico / Mansarda
#                        </a>
#                       </span>
#                      </label>
#                     </div>
#                    </div>
#                    <div class="col-xs-4">
#                     <div class="styled-radiobtn">
#                      <label>
#                       <input name="styled-radio-basic" type="checkbox"/>
#                       <span class="styled-radio">
#                        <i>
#                        </i>
#                       </span>
#                       <span>
#                        <a href="https://www.immobiliare.it/vendita-garage/roma/" title="Garage in vendita Roma">
#                         Box / Garage
#                        </a>
#                       </span>
#                      </label>
#                     </div>
#                    </div>
#                    <div class="col-xs-4">
#                     <div class="styled-radiobtn">
#                      <label>
#                       <input name="styled-radio-basic" type="checkbox"/>
#                       <span class="styled-radio">
#                        <i>
#                        </i>
#                       </span>
#                       <span>
#                        <a href="https://www.immobiliare.it/vendita-case-indipendenti/roma/" title="Case indipendenti in vendita Roma">
#                         Casa indipendente
#                        </a>
#                       </span>
#                      </label>
#                     </div>
#                    </div>
#                    <div class="col-xs-4">
#                     <div class="styled-radiobtn">
#                      <label>
#                       <input name="styled-radio-basic" type="checkbox"/>
#                       <span class="styled-radio">
#                        <i>
#                        </i>
#                       </span>
#                       <span>
#                        <a href="https://www.immobiliare.it/vendita-loft/roma/" title="Loft in vendita Roma">
#                         Loft / Open Space
#                        </a>
#                       </span>
#                      </label>
#                     </div>
#                    </div>
#                    <div class="col-xs-4">
#                     <div class="styled-radiobtn">
#                      <label>
#                       <input name="styled-radio-basic" type="checkbox"/>
#                       <span class="styled-radio">
#                        <i>
#                        </i>
#                       </span>
#                       <span>
#                        <a href="https://www.immobiliare.it/vendita-palazzi/roma/" title="Palazzi in vendita Roma">
#                         Palazzo / Stabile
#                        </a>
#                       </span>
#                      </label>
#                     </div>
#                    </div>
#                    <div class="col-xs-4">
#                     <div class="styled-radiobtn">
#                      <label>
#                       <input name="styled-radio-basic" type="checkbox"/>
#                       <span class="styled-radio">
#                        <i>
#                        </i>
#                       </span>
#                       <span>
#                        <a href="https://www.immobiliare.it/vendita-rustici/roma/" title="Rustici in vendita Roma">
#                         Rustico / Casale
#                        </a>
#                       </span>
#                      </label>
#                     </div>
#                    </div>
#                    <div class="col-xs-4">
#                     <div class="styled-radiobtn">
#                      <label>
#                       <input name="styled-radio-basic" type="checkbox"/>
#                       <span class="styled-radio">
#                        <i>
#                        </i>
#                       </span>
#                       <span>
#                        <a href="https://www.immobiliare.it/vendita-ville/roma/" title="Villa in vendita Roma">
#                         Villa
#                        </a>
#                       </span>
#                      </label>
#                     </div>
#                    </div>
#                    <div class="col-xs-4">
#                     <div class="styled-radiobtn">
#                      <label>
#                       <input name="styled-radio-basic" type="checkbox"/>
#                       <span class="styled-radio">
#                        <i>
#                        </i>
#                       </span>
#                       <span>
#                        <a href="https://www.immobiliare.it/vendita-villette/roma/" title="Villette in vendita Roma">
#                         Villetta a schiera
#                        </a>
#                       </span>
#                      </label>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                  <div class="clearfix foot-conferma">
#                   <a class="btn btn-action text-uppercase pull-right" data-action="confirm" role="button">
#                    conferma
#                   </a>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="col-content one-row-hidden col-content_prezzo">
#             <div class="dropdown dropdown-range dropdown-select hideLabelOnFilled" data-name="prezzo" data-role="range" tabindex="0">
#              <div class="dropdown-toggle form-control pointer component-form" data-action="toggle">
#               <div class="label-container">
#                Prezzo
#               </div>
#               <div class="value-container">
#                <span class="placeholder">
#                 Qualsiasi
#                </span>
#                <span data-role="display-value">
#                </span>
#               </div>
#               <span class="visible-xs-block caret-icon">
#               </span>
#              </div>
#              <div class="dropdown-menu dropdown-range" data-role="menu">
#               <div class="dropdown-menu__head visible-xs-block">
#                prezzo
#                <span class="closeMobile" data-action="toggle">
#                </span>
#               </div>
#               <ul>
#                <li class="range-dropdown-inputs clearfix">
#                 <div>
#                  <input autocomplete="off" class="form-control" data-role="range-min" name="prezzoMinimo" placeholder="Da:" type="tel" value=""/>
#                 </div>
#                 <div>
#                  <input autocomplete="off" class="form-control" data-role="range-max" name="prezzoMassimo" placeholder="A:" type="tel" value=""/>
#                 </div>
#                </li>
#                <li>
#                 <div class="dropdown-scroll-mobile">
#                  <ul class="dropdown-select-menu" data-role="shortcuts">
#                   <li>
#                    <a class="" data-value="50000" role="button">
#                     50.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="60000" role="button">
#                     60.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="70000" role="button">
#                     70.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="80000" role="button">
#                     80.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="90000" role="button">
#                     90.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="100000" role="button">
#                     100.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="120000" role="button">
#                     120.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="140000" role="button">
#                     140.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="160000" role="button">
#                     160.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="180000" role="button">
#                     180.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="200000" role="button">
#                     200.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="220000" role="button">
#                     220.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="240000" role="button">
#                     240.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="260000" role="button">
#                     260.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="280000" role="button">
#                     280.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="300000" role="button">
#                     300.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="320000" role="button">
#                     320.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="340000" role="button">
#                     340.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="360000" role="button">
#                     360.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="380000" role="button">
#                     380.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="400000" role="button">
#                     400.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="450000" role="button">
#                     450.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="500000" role="button">
#                     500.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="550000" role="button">
#                     550.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="600000" role="button">
#                     600.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="650000" role="button">
#                     650.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="700000" role="button">
#                     700.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="750000" role="button">
#                     750.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="800000" role="button">
#                     800.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="850000" role="button">
#                     850.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="900000" role="button">
#                     900.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="950000" role="button">
#                     950.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="1000000" role="button">
#                     1.000.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="1500000" role="button">
#                     1.500.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="2000000" role="button">
#                     2.000.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="2500000" role="button">
#                     2.500.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="3000000" role="button">
#                     3.000.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="3500000" role="button">
#                     3.500.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="4000000" role="button">
#                     4.000.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="4500000" role="button">
#                     4.500.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="5000000" role="button">
#                     5.000.000 €
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="" role="button">
#                     Indifferente
#                    </a>
#                   </li>
#                  </ul>
#                 </div>
#                </li>
#               </ul>
#               <div class="dropdown-menu__conferma visible-xs-block">
#                <div class="btn btn-action btn-block text-uppercase" data-action="toggle">
#                 Conferma
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="col-content one-row-hidden col-content_superficie">
#             <div class="dropdown dropdown-range dropdown-select hideLabelOnFilled" data-name="superficie" data-role="range" tabindex="0">
#              <div class="dropdown-toggle form-control pointer component-form" data-action="toggle">
#               <div class="label-container">
#                Superficie
#               </div>
#               <div class="value-container">
#                <span class="placeholder">
#                 Qualsiasi
#                </span>
#                <span data-role="display-value">
#                </span>
#               </div>
#               <span class="visible-xs-block caret-icon">
#               </span>
#              </div>
#              <div class="dropdown-menu dropdown-range" data-role="menu">
#               <div class="dropdown-menu__head visible-xs-block">
#                superficie
#                <span class="closeMobile" data-action="toggle">
#                </span>
#               </div>
#               <ul>
#                <li class="range-dropdown-inputs clearfix">
#                 <div>
#                  <input autocomplete="off" class="form-control" data-role="range-min" name="superficieMinima" placeholder="Da:" type="tel" value=""/>
#                 </div>
#                 <div>
#                  <input autocomplete="off" class="form-control" data-role="range-max" name="superficieMassima" placeholder="A:" type="tel" value=""/>
#                 </div>
#                </li>
#                <li>
#                 <div class="dropdown-scroll-mobile">
#                  <ul class="dropdown-select-menu" data-role="shortcuts">
#                   <li>
#                    <a class="" data-value="20" role="button">
#                     20 m²
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="40" role="button">
#                     40 m²
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="60" role="button">
#                     60 m²
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="80" role="button">
#                     80 m²
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="100" role="button">
#                     100 m²
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="120" role="button">
#                     120 m²
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="140" role="button">
#                     140 m²
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="160" role="button">
#                     160 m²
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="180" role="button">
#                     180 m²
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="200" role="button">
#                     200 m²
#                    </a>
#                   </li>
#                   <li>
#                    <a class="" data-value="300" role="button">
#                     300 m²
#                    </a>
#                   </li>
# ...
#       </div>
#       <div class="a-side__responsive hidden-xs">
#        <div class="price-chart">
#         <p class="h3 price-chart__container-title clearfix">
#          <a class="pull-left" href="https://www.immobiliare.it/prezzi-mq/Lazio/Roma.html" target="_blank" title="Prezzi case in vendita Roma">
#           <span class="price-chart__title">
#            Prezzi case in vendita
#           </span>
#           <br/>
#           <span class="price-chart__subtitle">
#            Roma
#           </span>
#          </a>
#          <span class="btn btn-primary btn-xs btn-revert open-win price-chart__btn price-chart__btn--desktop" data-href="https://www.immobiliare.it/mercato-immobiliare/Lazio/Roma.html">
#           VEDI
#          </span>
#          <span class="btn btn-primary btn-xs btn-revert open-win price-chart__btn price-chart__btn--tablet" data-href="https://www.immobiliare.it/mercato-immobiliare/Lazio/Roma.html">
#           vedi tutti i prezzi
#          </span>
#         </p>
#         <div class="price-chart__chart price-chart__chart--desktop">
#          <div style="height: 0; overflow: hidden;">
#           <iframe data-src="https://www.immobiliare.it/guide_locali/get_charts.php?id=6737&amp;livelloGeo=comune&amp;graph=vendita&amp;version=2" id="priceChart">
#           </iframe>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="a-side__desktop">
#        <div class="banner">
#         <div class="dfpPosition visible-lg-block visible-md-block visible-sm-block" style="display:block;">
#          <div id="div-gpt-ad-1491564297386-0" style="margin:10px auto;width:300px;">
#          </div>
#         </div>
#        </div>
#        <div class="banner">
#         <div class="dfpPosition visible-lg-block visible-md-block visible-sm-block" style="display:block;">
#          <div id="div-gpt-ad-1490014782721-0" style="margin:10px auto;width:300px;">
#          </div>
#         </div>
#        </div>
#        <div class="box-container box-container-agency premium-agency" id="boxAgenziePremium" style="display: none;">
#         <p class="h3 box-container-title">
#          In evidenza
#         </p>
#         <div data-role="container-data">
#         </div>
#        </div>
#        <div class="banner">
#         <div class="dfpPosition visible-lg-block visible-md-block visible-sm-block" style="display:block;">
#          <div id="div-gpt-ad-1476096613411-0" style="margin:10px auto;width:300px;">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="slim hidden-xs" id="footer" role="contentinfo">
#    <div class="container footer-links" role="navigation">
#     <div class="row">
#      <div class="col-xs-12 col-md-2">
#       <p class="h5">
#        Immobiliare.it
#       </p>
#      </div>
#      <div class="col-xs-12 col-md-10">
#       <ul class="list-inline list-piped">
#        <li>
#         <a href="https://www.immobiliare.it/info/chi-siamo/" rel="nofollow">
#          Chi siamo
#         </a>
#        </li>
#        <li class="piped-white">
#         <a href="https://www.immobiliare.it/info/ufficio-stampa/" rel="nofollow">
#          Ufficio
#                             stampa
#         </a>
#        </li>
#        <li class="piped-white">
#         <a href="https://www.immobiliare.it/info/lavora-con-noi/" rel="nofollow">
#          Lavora con
#                             noi
#         </a>
#        </li>
#        <li class="piped-white">
#         <a href="https://www.immobiliare.it/info/pubblicita/" rel="nofollow">
#          Pubblicità
#         </a>
#        </li>
#        <li class="piped-white">
#         <a href="https://www.immobiliare.it/vendita-case/roma/?mode=rss" rel="nofollow">
#          RSS
#         </a>
#        </li>
#        <li class="piped-white">
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="row">
#      <div class="col-xs-12 col-md-2">
#       <p class="h5">
#        Agenzie e Costruttori
#       </p>
#      </div>
#      <div class="col-xs-12 col-md-10">
#       <ul class="list-inline list-piped">
#        <li>
#         <a href="https://www.immobiliare.it/info/leader/" rel="nofollow">
#          Perché siamo i
#                             leader
#         </a>
#        </li>
#        <li class="piped-white">
#         <a href="https://www.immobiliare.it/info/pubblicazione-annunci/" rel="nofollow">
#          Pubblicazione
#                             annunci
#         </a>
#        </li>
#        <li class="piped-white">
#         <a href="https://www.immobiliare.it/info/software-immobiliare/" rel="nofollow">
#          Software
#                             gestionale
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="row">
#      <div class="col-xs-12 col-md-2">
#       <p class="h5">
#        Privati
#       </p>
#      </div>
#      <div class="col-xs-12 col-md-10">
#       <ul class="list-inline list-piped">
#        <li>
#         <a href="https://www.immobiliare.it/inserimento_annuncio_privati.php" rel="nofollow">
#          Pubblica
#                             annuncio
#         </a>
#        </li>
#        <li class="piped-white">
#         <a href="https://www.immobiliare.it/valutazione_immobiliare.php" rel="nofollow">
#          Valuta
#                             casa
#         </a>
#        </li>
#        <li class="piped-white">
#         <a href="https://www.immobiliare.it/mutui/" rel="nofollow">
#          Mutui
#         </a>
#        </li>
#        <li class="piped-white">
#         <a href="http://www.casevacanza.it" rel="nofollow">
#          Case Vacanza
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="footer-disclaimer" role="contentinfo">
#    <div class="container">
#     <div class="col-xs-12 col-md-3 pull-right text-right disclaimer-right" id="footer-social-menu">
#      <span class="raleway">
#       Seguici su
#      </span>
#      <a href="https://twitter.com/immobiliare_it" rel="nofollow" target="_blank">
#       <i class="icon icon-footer-twitter">
#       </i>
#      </a>
#      <a href="https://www.facebook.com/immobiliare.it/" rel="nofollow" target="_blank">
#       <i class="icon icon-footer-facebook">
#       </i>
#      </a>
#      <a href="https://www.instagram.com/immobiliare_it/" rel="nofollow" target="_blank">
#       <i class="icon icon-footer-instagram">
#       </i>
#      </a>
#     </div>
#     <div class="col-xs-12 col-md-9 pull-left text-left disclaimer-left">
#      <span class="disclaimer-block--mobile">
#       <span>
#        © 2018
#                 Immobiliare.it
#       </span>
#      </span>
#      <span class="disclaimer-block--mobile piped-left piped-white">
#       <a href="https://www.immobiliare.it/terms/" rel="nofollow">
#        Condizioni
#                 Generali
#       </a>
#       ,
#       <a href="https://www.immobiliare.it/terms/privacy/" rel="nofollow">
#        Regole
#                 della Privacy
#       </a>
#       e
#       <a href="https://www.immobiliare.it/terms/cookie/" rel="nofollow">
#        Uso
#                 dei Cookie
#       </a>
#      </span>
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    var _gaq=_gaq||[];var pluginUrl="//www.google-analytics.com/plugins/ga/inpage_linkid.js";_gaq.push(["_setAccount",globalVars.GOOGLE_ANALYTICS_CODE]);_gaq.push(["_setDomainName",globalVars.GOOGLE_ANALYTICS_DOMAIN]);_gaq.push(["_require","inpage_linkid",pluginUrl]);_gaq.push(["_addIgnoredRef",globalVars.GOOGLE_ANALYTICS_DOMAIN]);_gaq.push(["_addIgnoredRef","."+globalVars.GOOGLE_ANALYTICS_DOMAIN]);(function(){var ga=document.createElement("script");ga.type="text/javascript";ga.async=true;if(!window.readCookie||!window.readCookie('cookieBanner')){ga.src =('https:'==document.location.protocol?'https://ssl':'http://www')+'.google-analytics.com/ga.js';}else{ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';};var s=document.getElementsByTagName("script")[0];s.parentNode.insertBefore(ga,s)})();(function(i,s,o,g,r,a,m){i.GoogleAnalyticsObject=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","//www.google-analytics.com/analytics.js","ga");ga("create",globalVars.GOOGLE_ANALYTICS_UNIVERSAL_CODE,{cookieDomain:globalVars.GOOGLE_ANALYTICS_DOMAIN});ga("require","linkid","linkid.js");
#   </script>
#   <script>
#    if (!window.readCookie || !window.readCookie('cookieBanner')){_gaq.push (['_gat._anonymizeIp']);ga('set', 'anonymizeIp', true);}
#   </script>
#   <script>
#    !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '1432880790300514');
#   </script>
#   <script id="js-hydration" type="application/json">
#    {"ads":{"70453446":{"pk":"70453446","isProgetto":false,"bagni":"2","locali":"2","idAgenzia":"38381","prezzo":"\u20ac 395.000","superficie":"90","idUba":null,"fbTracking":{"value":"395000","currency":"EUR","region":"Roma","city":"Roma","country":"Italia","content_category":"Vendita","content_type":["hotel","product","home_listing"],"destination":"Residenziale","property_type":"apartment","availability":"for_sale","listing_type":"for_sale_by_agent","content_ids":"70453446"}},"70454576":{"pk":"70454576","isProgetto":false,"bagni":"1","locali":"2","idAgenzia":"55266","prezzo":"\u20ac 410.000","superficie":"45","idUba":null,"fbTracking":{"value":"410000","currency":"EUR","region":"Roma","city":"Roma","country":"Italia","content_category":"Vendita","content_type":["hotel","product","home_listing"],"destination":"Residenziale","property_type":"apartment","availability":"for_sale","listing_type":"for_sale_by_agent","content_ids":"70454576"}},"70457896":{"pk":"70457896","isProgetto":false,"bagni":"1","locali":"4","idAgenzia":"182236","prezzo":"\u20ac 295.000","superficie":"116","idUba":null,"fbTracking":{"value":"295000","currency":"EUR","region":"Roma","city":"Roma","country":"Italia","content_category":"Vendita","content_type":["hotel","product","home_listing"],"destination":"Residenziale","property_type":"apartment","availability":"for_sale","listing_type":"for_sale_by_agent","content_ids":"70457896"}},"70454426":{"pk":"70454426","isProgetto":false,"bagni":"2","locali":"5+","idAgenzia":"55266","prezzo":"\u20ac 465.000","superficie":"175","idUba":null,"fbTracking":{"value":"465000","currency":"EUR","region":"Roma","city":"Roma","country":"Italia","content_category":"Vendita","content_type":["hotel","product","home_listing"],"destination":"Residenziale","property_type":"apartment","availability":"for_sale","listing_type":"for_sale_by_agent","content_ids":"70454426"}},"70454428":{"pk":"70454428","isProgetto":false,"bagni":"2","locali":"3","idAgenzia":"55266","prezzo":"\u20ac 439.000","superficie":"145","idUba":null,"fbTracking":{"value":"439000","currency":"EUR","region":"Roma","city":"Roma","country":"Italia","content_category":"Vendita","content_type":["hotel","product","home_listing"],"destination":"Residenziale","property_type":"apartment","availability":"for_sale","listing_type":"for_sale_by_agent","content_ids":"70454428"}},"70456964":{"pk":"70456964","isProgetto":false,"bagni":"1","locali":"4","idAgenzia":"55266","prezzo":"\u20ac 350.000","superficie":"100","idUba":null,"fbTracking":{"value":"350000","currency":"EUR","region":"Roma","city":"Roma","country":"Italia","content_category":"Vendita","content_type":["hotel","product","home_listing"],"destination":"Residenziale","property_type":"apartment","availability":"for_sale","listing_type":"for_sale_by_agent","content_ids":"70456964"}},"70457930":{"pk":"70457930","isProgetto":false,"bagni":"1","locali":"2","idAgenzia":"105266","prezzo":"\u20ac 245.000","superficie":"75","idUba":null,"fbTracking":{"value":"245000","currency":"EUR","region":"Roma","city":"Roma","country":"Italia","content_category":"Vendita","content_type":["hotel","product","home_listing"],"destination":"Residenziale","property_type":"apartment","availability":"for_sale","listing_type":"for_sale_by_agent","content_ids":"70457930"}},"70454586":{"pk":"70454586","isProgetto":false,"bagni":"2","locali":"5+","idAgenzia":"105266","prezzo":"\u20ac 1.095.000","superficie":"180","idUba":null,"fbTracking":{"value":"1095000","currency":"EUR","region":"Roma","city":"Roma","country":"Italia","content_category":"Vendita","content_type":["hotel","product","home_listing"],"destination":"Residenziale","property_type":"apartment","availability":"for_sale","listing_type":"for_sale_by_agent","content_ids":"70454586"}},"70454340":{"pk":"70454340","isProgetto":false,"bagni":"3","locali":"5+","idAgenzia":"105266","prezzo":"\u20ac 1.280.000","superficie":"230","idUba":null,"fbTracking":{"value":"1280000","currency":"EUR","region":"Rom ...
#   </script>
#   <script src="https://js.im-cdn.it/assets/2018112701/js/jquery.js">
#   </script>
#   <!--[if lte IE 9]>
#   <script src="https://js.im-cdn.it/assets/2018112701/js/polyfills-body.js"></script>
#   <![endif]-->
#   <script src="https://js.im-cdn.it/assets/2018112701/js/listing.js">
#   </script>
#   <link href="https://css.im-cdn.it/assets/2018112701/css/chunks/base.css" media="not all" onload="if(media!='all')media='all'" rel="stylesheet"/>
#   <link href="https://css.im-cdn.it/assets/2018112701/css/chunks/listing.css" media="not all" onload="if(media!='all')media='all'" rel="stylesheet"/>
#   <div style="height:0px; overflow: hidden">
#    <script>
#     fbq('track', 'PageView');
#    </script>
#    <noscript>
#     <img alt="" height="1" src="https://www.facebook.com/tr?id=1432880790300514&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#    </noscript>
#    <script>
#     if(window._gaq){_gaq.push(["_trackPageview"])}if(window.ga){if (siteConfigs && siteConfigs.user && siteConfigs.user.hashedEmail) {ga('set', 'userId', siteConfigs.user.hashedEmail);}ga("send","pageview")};
#    </script>
#    <script class="tracking-tag" data-src="https://js.im-cdn.it/assets/2018112701/js/externals/tracking-listing-config.js">
#    </script>
#    <img alt="bluelithium" class="tracking-tag" data-src="//ads.bluelithium.com/pixel?id=951774&amp;t=2" height="1" width="1">
#     <img alt="" class="tracking-tag" data-src="//bat.bing.com/action/0?ti=5268061&amp;Ver=2" height="0" style="display:none; visibility: hidden;" width="0">
#      <img alt="" class="tracking-tag" data-src="https://ad.doubleclick.net/ddm/activity/src=6490605;type=invmedia;cat=1fcdkqti;dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;ord=1?" height="1" width="1"/>
#      <img alt="" class="tracking-tag" data-src="https://go.turboadv.com/tr?id=15394&amp;ad=15532&amp;e=pv&amp;rt=img" height="1" width="1"/>
#      <script class="tracking-tag" data-src="https://js.im-cdn.it/assets/2018112701/js/externals/tracking-loader.js">
#      </script>
#      <script>
#       readCookie('cookieBanner') && Array.prototype.slice.call(document.querySelectorAll('.tracking-tag')).forEach(function(node) { node.src = node.getAttribute('data-src') })
#      </script>
#      <script>
#       readCookie('cookieBanner') && document.write('<script type="text/javascript" src="//www.googleadservices.com/pagead/conversion.js"><\/script>')
#      </script>
#      <script class="hidden" id="contact-conversion-trackers" type="application/json">
#       ["https://www.facebook.com/tr?id=1432880790300514&ev=Lead","//ads.bluelithium.com/pixel?id=951782&amp;t=2","//bat.bing.com/action/0?ti=5268061&Ver=2","//rd.trovit.com/conversion/it/1/e9db2d2c0148f35c8465dff725c3c584/","https://track.adform.net/Serving/TrackPoint/?pm=201325&ADFPageName=immo_opt&ADFdivider=|", "//googleads.g.doubleclick.net/pagead/viewthroughconversion/1066595945/?value=0&guid=ON&script=0&data=dynx_pagetype=conversion","https://ad.doubleclick.net/ddm/activity/src=6490605;type=invmedia;cat=0diihaqc;dc_lat=;dc_rdid=;tag_for_child_directed_treatment=;ord=1?"]
#      </script>
#     </img>
#    </img>
#   </div>
#  </body>
# </html>

# %%
soup = BeautifulSoup(, "lxml")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-593987f9a701> in <module>()
#       1 from bs4 import BeautifulSoup
#       2
# ----> 3 soup = BeautifulSoup(response, "lxml")
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     244         if hasattr(markup, 'read'):        # It's a file-type object.
#     245             markup = markup.read()
# --> 246         elif len(markup) <= 256 and (
#     247                 (isinstance(markup, bytes) and not b'<' in markup)
#     248                 or (isinstance(markup, str) and not '<' in markup)
#
# TypeError: object of type 'Response' has no len()

# %%
for link in soup.find_all(''):
    if (link.get('href').startswith('/vendita-case/')):
        print(link.get('href'))
